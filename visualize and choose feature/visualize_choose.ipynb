# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as ptl

# %%
data=pd.read_csv("player_date_with_no_outlayer.csv")
print(data.shape)
data.head()
# Out:
# (12598, 84)
#    age  height_cm  weight_kgs  nationality  overall_rating  potential  \
# 0   26     1.7272        73.9           22              64         65
# 1   32     1.8796        79.8           76              72         72
# 2   24     1.7526        68.0          118              71         78
# 3   31     1.8796        83.0           44              72         72
# 4   24     1.7526        74.8           80              64         71
#
#        wage  preferred_foot  international_reputation(1-5)  weak_foot(1-5)  \
# 0  0.000000               1                              1               3
# 1  0.022026               1                              2               3
# 2  0.019824               1                              1               3
# 3  0.070485               0                              1               3
# 4  0.000000               1                              1               3
#
#    ...    CB   RCB    RB  position_first  position_second  position_third  \
# 0  ...  52.0  52.0  58.0               7               11               0
# 1  ...  73.0  73.0  60.0               1                0               0
# 2  ...  49.0  49.0  53.0              14                7               0
# 3  ...  72.0  72.0  72.0               6                9               0
# 4  ...  60.0  60.0  63.0              13               11               0
#
#    upper_work_rate  down_work_rate  num_of_work_rate      value
# 0                1               3          0.333333   525000.0
# 1                2               3          0.666667  1800000.0
# 2                1               3          0.333333  3400000.0
# 3                1               1          1.000000  2200000.0
# 4                3               3          1.000000   525000.0
#
# [5 rows x 84 columns]

# %%
corr= data.corr()
corr
# Out:
#                        age  height_cm  weight_kgs  nationality  \
# age               1.000000   0.064455    0.238344    -0.031627
# height_cm         0.064455   1.000000    0.494736     0.012074
# weight_kgs        0.238344   0.494736    1.000000    -0.009525
# nationality      -0.031627   0.012074   -0.009525     1.000000
# overall_rating    0.539554   0.041004    0.159080    -0.017866
# ...                    ...        ...         ...          ...
# position_third    0.020720  -0.117886   -0.116906     0.000939
# upper_work_rate  -0.061613   0.143427    0.144274    -0.014351
# down_work_rate   -0.133772   0.014802   -0.010304     0.007717
# num_of_work_rate  0.079057   0.072507    0.095093    -0.012462
# value             0.180009   0.007265    0.053996    -0.015632
#
#                   overall_rating  potential      wage  preferred_foot  \
# age                     0.539554  -0.352586  0.280392       -0.012798
# height_cm               0.041004  -0.001765  0.025484        0.044230
# weight_kgs              0.159080  -0.054363  0.084882        0.065032
# nationality            -0.017866   0.002148 -0.023459        0.012216
# overall_rating          1.000000   0.463684  0.570585       -0.065847
# ...                          ...        ...       ...             ...
# position_third          0.091390   0.032595  0.045776       -0.008041
# upper_work_rate        -0.164627  -0.069774 -0.102531        0.058751
# down_work_rate         -0.165920  -0.031060 -0.097143       -0.018594
# num_of_work_rate        0.048384  -0.012885  0.022007        0.042825
# value                   0.734112   0.537203  0.656400       -0.034599
#
#                   international_reputation(1-5)  weak_foot(1-5)  ...  \
# age                                    0.289026        0.058051  ...
# height_cm                              0.024495       -0.122849  ...
# weight_kgs                             0.082092       -0.129704  ...
# nationality                            0.004116        0.001324  ...
# overall_rating                         0.270107        0.163550  ...
# ...                                         ...             ...  ...
# position_third                        -0.003578        0.123574  ...
# upper_work_rate                       -0.019384       -0.132570  ...
# down_work_rate                        -0.046361       -0.056689  ...
# num_of_work_rate                       0.026192       -0.037021  ...
# value                                  0.237263        0.132500  ...
#
#                         CB       RCB        RB  position_first  \
# age               0.337290  0.337290  0.315759       -0.057328
# height_cm         0.150745  0.150745  0.008465       -0.131249
# weight_kgs        0.269634  0.269634  0.081668       -0.114276
# nationality      -0.000007 -0.000007  0.000178        0.014524
# overall_rating    0.405349  0.405349  0.477063       -0.028370
# ...                    ...       ...       ...             ...
# position_third   -0.078977 -0.078977  0.002874        0.065592
# upper_work_rate   0.076328  0.076328 -0.004282       -0.214541
# down_work_rate   -0.178182 -0.178182 -0.146923        0.073604
# num_of_work_rate  0.255918  0.255918  0.173435       -0.227908
# value             0.240242  0.240242  0.317611        0.010728
#
#                   position_second  position_third  upper_work_rate  \
# age                      0.007630        0.020720        -0.061613
# height_cm               -0.221869       -0.117886         0.143427
# weight_kgs              -0.241943       -0.116906         0.144274
# nationality             -0.007695        0.000939        -0.014351
# overall_rating           0.122505        0.091390        -0.164627
# ...                           ...             ...              ...
# position_third           0.336945        1.000000        -0.111979
# upper_work_rate         -0.174889       -0.111979         1.000000
# down_work_rate          -0.046144       -0.035417         0.131053
# num_of_work_rate        -0.067245       -0.041269         0.486887
# value                    0.095892        0.073573        -0.149647
#
#                   down_work_rate  num_of_work_rate     value
# age                    -0.133772          0.079057  0.180009
# height_cm               0.014802          0.072507  0.007265
# weight_kgs             -0.010304          0.095093  0.053996
# nationality             0.007717         -0.012462 -0.015632
# overall_rating         -0.165920          0.048384  0.734112
# ...                          ...               ...       ...
# position_third         -0.035417         -0.041269  0.073573
# upper_work_rate         0.131053          0.486887 -0.149647
# down_work_rate          1.000000         -0.734878 -0.114648
# num_of_work_rate       -0.734878          1.000000  0.004883
# value                  -0.114648          0.004883  1.000000
#
# [84 rows x 84 columns]

# %%
ptl.figure(figsize=(50,50))
sns.set_context('paper',font_scale=1)
sns.heatmap(data.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
corr
# Out:
#                        age  height_cm  weight_kgs  nationality  \
# age               1.000000   0.064455    0.238344    -0.031627
# height_cm         0.064455   1.000000    0.494736     0.012074
# weight_kgs        0.238344   0.494736    1.000000    -0.009525
# nationality      -0.031627   0.012074   -0.009525     1.000000
# overall_rating    0.539554   0.041004    0.159080    -0.017866
# ...                    ...        ...         ...          ...
# position_third    0.020720  -0.117886   -0.116906     0.000939
# upper_work_rate  -0.061613   0.143427    0.144274    -0.014351
# down_work_rate   -0.133772   0.014802   -0.010304     0.007717
# num_of_work_rate  0.079057   0.072507    0.095093    -0.012462
# value             0.180009   0.007265    0.053996    -0.015632
#
#                   overall_rating  potential      wage  preferred_foot  \
# age                     0.539554  -0.352586  0.280392       -0.012798
# height_cm               0.041004  -0.001765  0.025484        0.044230
# weight_kgs              0.159080  -0.054363  0.084882        0.065032
# nationality            -0.017866   0.002148 -0.023459        0.012216
# overall_rating          1.000000   0.463684  0.570585       -0.065847
# ...                          ...        ...       ...             ...
# position_third          0.091390   0.032595  0.045776       -0.008041
# upper_work_rate        -0.164627  -0.069774 -0.102531        0.058751
# down_work_rate         -0.165920  -0.031060 -0.097143       -0.018594
# num_of_work_rate        0.048384  -0.012885  0.022007        0.042825
# value                   0.734112   0.537203  0.656400       -0.034599
#
#                   international_reputation(1-5)  weak_foot(1-5)  ...  \
# age                                    0.289026        0.058051  ...
# height_cm                              0.024495       -0.122849  ...
# weight_kgs                             0.082092       -0.129704  ...
# nationality                            0.004116        0.001324  ...
# overall_rating                         0.270107        0.163550  ...
# ...                                         ...             ...  ...
# position_third                        -0.003578        0.123574  ...
# upper_work_rate                       -0.019384       -0.132570  ...
# down_work_rate                        -0.046361       -0.056689  ...
# num_of_work_rate                       0.026192       -0.037021  ...
# value                                  0.237263        0.132500  ...
#
#                         CB       RCB        RB  position_first  \
# age               0.337290  0.337290  0.315759       -0.057328
# height_cm         0.150745  0.150745  0.008465       -0.131249
# weight_kgs        0.269634  0.269634  0.081668       -0.114276
# nationality      -0.000007 -0.000007  0.000178        0.014524
# overall_rating    0.405349  0.405349  0.477063       -0.028370
# ...                    ...       ...       ...             ...
# position_third   -0.078977 -0.078977  0.002874        0.065592
# upper_work_rate   0.076328  0.076328 -0.004282       -0.214541
# down_work_rate   -0.178182 -0.178182 -0.146923        0.073604
# num_of_work_rate  0.255918  0.255918  0.173435       -0.227908
# value             0.240242  0.240242  0.317611        0.010728
#
#                   position_second  position_third  upper_work_rate  \
# age                      0.007630        0.020720        -0.061613
# height_cm               -0.221869       -0.117886         0.143427
# weight_kgs              -0.241943       -0.116906         0.144274
# nationality             -0.007695        0.000939        -0.014351
# overall_rating           0.122505        0.091390        -0.164627
# ...                           ...             ...              ...
# position_third           0.336945        1.000000        -0.111979
# upper_work_rate         -0.174889       -0.111979         1.000000
# down_work_rate          -0.046144       -0.035417         0.131053
# num_of_work_rate        -0.067245       -0.041269         0.486887
# value                    0.095892        0.073573        -0.149647
#
#                   down_work_rate  num_of_work_rate     value
# age                    -0.133772          0.079057  0.180009
# height_cm               0.014802          0.072507  0.007265
# weight_kgs             -0.010304          0.095093  0.053996
# nationality             0.007717         -0.012462 -0.015632
# overall_rating         -0.165920          0.048384  0.734112
# ...                          ...               ...       ...
# position_third         -0.035417         -0.041269  0.073573
# upper_work_rate         0.131053          0.486887 -0.149647
# down_work_rate          1.000000         -0.734878 -0.114648
# num_of_work_rate       -0.734878          1.000000  0.004883
# value                  -0.114648          0.004883  1.000000
#
# [84 rows x 84 columns]

# %%
top_feature = corr.index[abs(corr['value'])>0.5]
top_feature
# Out:
# Index(['overall_rating', 'potential', 'wage', 'release_clause_euro',
#        'reactions', 'value'],
#       dtype='object')

# %%
df=data[top_feature]
print(df.shape)
df.head()
# Out:
# (12598, 6)
#    overall_rating  potential      wage  release_clause_euro  reactions  \
# 0              64         65  0.000000             0.003944         61
# 1              72         72  0.022026             0.015952         65
# 2              71         78  0.019824             0.035473         64
# 3              72         72  0.070485             0.021458         68
# 4              64         71  0.000000             0.003744         60
#
#        value
# 0   525000.0
# 1  1800000.0
# 2  3400000.0
# 3  2200000.0
# 4   525000.0

# %%
ptl.figure(figsize=(50,50))
sns.set_context('paper',font_scale=1.4)
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
df.to_csv("data_with_feature_chooseing.csv")
