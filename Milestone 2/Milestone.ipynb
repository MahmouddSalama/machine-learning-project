# %% [markdown]
# impor lips

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# read data

# %%
dataframe=pd.read_csv("player-classification.csv")
print(dataframe.shape)
dataframe.head(3)
# Out:
# (14363, 92)
#        id          name         full_name birth_date  age  height_cm  \
# 0  210824  F. Tchenkoua  Fabien Tchenkoua  10/1/1992   26     172.72
# 1  172835  M. Andreolli   Marco Andreolli  6/10/1986   32     187.96
# 2  212223    S. Maguire      Sean Maguire   5/1/1994   24     175.26
#
#    weight_kgs positions          nationality  overall_rating  ...   LDM   CDM  \
# 0        73.9     LM,RM             Cameroon              64  ...  51+2  51+2
# 1        79.8        CB                Italy              72  ...  61+2  61+2
# 2        68.0     ST,LM  Republic of Ireland              71  ...  48+2  48+2
#
#     RDM   RWB    LB   LCB    CB   RCB    RB PlayerLevel
# 0  51+2  57+2  56+2  50+2  50+2  50+2  56+2           C
# 1  61+2  54+2  58+2  71+2  71+2  71+2  58+2           A
# 2  48+2  53+2  51+2  47+2  47+2  47+2  51+2           A
#
# [3 rows x 92 columns]

# %% [markdown]
# data info

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14363 entries, 0 to 14362
# Data columns (total 92 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   id                             14363 non-null  int64
#  1   name                           14363 non-null  object
#  2   full_name                      14363 non-null  object
#  3   birth_date                     14363 non-null  object
#  4   age                            14363 non-null  int64
#  5   height_cm                      14363 non-null  float64
#  6   weight_kgs                     14363 non-null  float64
#  7   positions                      14363 non-null  object
#  8   nationality                    14363 non-null  object
#  9   overall_rating                 14363 non-null  int64
#  10  potential                      14363 non-null  int64
#  11  wage                           14172 non-null  float64
#  12  preferred_foot                 14363 non-null  object
#  13  international_reputation(1-5)  14363 non-null  int64
#  14  weak_foot(1-5)                 14363 non-null  int64
#  15  skill_moves(1-5)               14363 non-null  int64
#  16  work_rate                      14363 non-null  object
#  17  body_type                      14363 non-null  object
#  18  release_clause_euro            12881 non-null  float64
#  19  club_team                      14351 non-null  object
#  20  club_rating                    14351 non-null  float64
#  21  club_position                  14351 non-null  object
#  22  club_jersey_number             14351 non-null  float64
#  23  club_join_date                 12798 non-null  object
#  24  contract_end_year              14076 non-null  object
#  25  national_team                  688 non-null    object
#  26  national_rating                688 non-null    float64
#  27  national_team_position         688 non-null    object
#  28  national_jersey_number         688 non-null    float64
#  29  crossing                       14363 non-null  int64
#  30  finishing                      14363 non-null  int64
#  31  heading_accuracy               14363 non-null  int64
#  32  short_passing                  14363 non-null  int64
#  33  volleys                        14363 non-null  int64
#  34  dribbling                      14363 non-null  int64
#  35  curve                          14363 non-null  int64
#  36  freekick_accuracy              14363 non-null  int64
#  37  long_passing                   14363 non-null  int64
#  38  ball_control                   14363 non-null  int64
#  39  acceleration                   14363 non-null  int64
#  40  sprint_speed                   14363 non-null  int64
#  41  agility                        14363 non-null  int64
#  42  reactions                      14363 non-null  int64
#  43  balance                        14363 non-null  int64
#  44  shot_power                     14363 non-null  int64
#  45  jumping                        14363 non-null  int64
#  46  stamina                        14363 non-null  int64
#  47  strength                       14363 non-null  int64
#  48  long_shots                     14363 non-null  int64
#  49  aggression                     14363 non-null  int64
#  50  interceptions                  14363 non-null  int64
#  51  positioning                    14363 non-null  int64
#  52  vision                         14363 non-null  int64
#  53  penalties                      14363 non-null  int64
#  54  composure                      14363 non-null  int64
#  55  marking                        14363 non-null  int64
#  56  standing_tackle                14363 non-null  int64
#  57  sliding_tackle                 14363 non-null  int64
#  58  GK_diving                      14363 non-null  int64
#  59  GK_handling                    14363 non-null  int64
#  60  GK_kicking                     14363 non-null  int64
#  61  GK_positioning                 14363 non-null  int64
#  62  GK_reflexes                    14363 non-null  int64
#  63  tags                           1121 non-null   object
#  64  traits                         6504 non-null   object
#  65  LS                             12691 non-null  object
#  66  ST                             12691 non-null  object
#  67  RS                             12691 non-null  object
#  68  LW                             12691 non-null  object
#  69  LF                             12691 non-null  object
#  70  CF                             12691 non-null  object
#  71  RF                             12691 non-null  object
#  72  RW                             12691 non-null  object
#  73  LAM                            12691 non-null  object
#  74  CAM                            12691 non-null  object
#  75  RAM                            12691 non-null  object
#  76  LM                             12691 non-null  object
#  77  LCM                            12691 non-null  object
#  78  CM                             12691 non-null  object
#  79  RCM                            12691 non-null  object
#  80  RM                             12691 non-null  object
#  81  LWB                            12691 non-null  object
#  82  LDM                            12691 non-null  object
#  83  CDM                            12691 non-null  object
#  84  RDM                            12691 non-null  object
#  85  RWB                            12691 non-null  object
#  86  LB                             12691 non-null  object
#  87  LCB                            12691 non-null  object
#  88  CB                             12691 non-null  object
#  89  RCB                            12691 non-null  object
#  90  RB                             12691 non-null  object
#  91  PlayerLevel                    14363 non-null  object
# dtypes: float64(8), int64(41), object(43)
# memory usage: 10.1+ MB

# %% [markdown]
# data describe

# %%
dataframe.describe()
# Out:
#                   id           age     height_cm    weight_kgs  \
# count   14363.000000  14363.000000  14363.000000  14363.000000
# mean   215308.410569     25.575367    174.902069     75.304268
# std     29906.749470      4.700271     14.056556      7.085472
# min        16.000000     17.000000    152.400000     49.900000
# 25%    200913.000000     22.000000    154.940000     69.900000
# 50%    222771.000000     25.000000    175.260000     74.800000
# 75%    237607.000000     29.000000    185.420000     79.800000
# max    247607.000000     45.000000    205.740000    110.200000
#
#        overall_rating     potential           wage  \
# count    14363.000000  14363.000000   14172.000000
# mean        66.257676     71.435355    9888.371437
# std          6.958515      6.120675   21943.412002
# min         47.000000     48.000000    1000.000000
# 25%         62.000000     67.000000    1000.000000
# 50%         66.000000     71.000000    3000.000000
# 75%         71.000000     75.000000    9000.000000
# max         94.000000     95.000000  455000.000000
#
#        international_reputation(1-5)  weak_foot(1-5)  skill_moves(1-5)  ...  \
# count                   14363.000000    14363.000000      14363.000000  ...
# mean                        1.110701        2.946738          2.358560  ...
# std                         0.392804        0.662851          0.762557  ...
# min                         1.000000        1.000000          1.000000  ...
# 25%                         1.000000        3.000000          2.000000  ...
# 50%                         1.000000        3.000000          2.000000  ...
# 75%                         1.000000        3.000000          3.000000  ...
# max                         5.000000        5.000000          5.000000  ...
#
#           penalties     composure       marking  standing_tackle  \
# count  14363.000000  14363.000000  14363.000000     14363.000000
# mean      48.354244     58.680847     47.091207        47.676460
# std       15.845945     11.628867     20.106413        21.763713
# min        5.000000     12.000000      3.000000         2.000000
# 25%       38.000000     51.000000     29.000000        26.000000
# 50%       49.000000     60.000000     52.000000        55.000000
# 75%       60.000000     67.000000     64.000000        66.000000
# max       92.000000     95.000000     94.000000        93.000000
#
#        sliding_tackle     GK_diving  GK_handling    GK_kicking  \
# count    14363.000000  14363.000000  14363.00000  14363.000000
# mean        45.678619     16.841537     16.62111     16.431247
# std         21.359824     17.968259     17.17393     16.761096
# min          4.000000      1.000000      1.00000      1.000000
# 25%         24.000000      8.000000      8.00000      8.000000
# 50%         52.000000     11.000000     11.00000     11.000000
# 75%         64.000000     14.000000     14.00000     14.000000
# max         90.000000     90.000000     92.00000     91.000000
#
#        GK_positioning   GK_reflexes
# count    14363.000000  14363.000000
# mean        16.595558     16.952447
# std         17.328204     18.265496
# min          1.000000      1.000000
# 25%          8.000000      8.000000
# 50%         11.000000     11.000000
# 75%         14.000000     14.000000
# max         90.000000     94.000000
#
# [8 rows x 49 columns]

# %% [markdown]
# data columns

# %%
dataframe.columns
# Out:
# Index(['id', 'name', 'full_name', 'birth_date', 'age', 'height_cm',
#        'weight_kgs', 'positions', 'nationality', 'overall_rating', 'potential',
#        'wage', 'preferred_foot', 'international_reputation(1-5)',
#        'weak_foot(1-5)', 'skill_moves(1-5)', 'work_rate', 'body_type',
#        'release_clause_euro', 'club_team', 'club_rating', 'club_position',
#        'club_jersey_number', 'club_join_date', 'contract_end_year',
#        'national_team', 'national_rating', 'national_team_position',
#        'national_jersey_number', 'crossing', 'finishing', 'heading_accuracy',
#        'short_passing', 'volleys', 'dribbling', 'curve', 'freekick_accuracy',
#        'long_passing', 'ball_control', 'acceleration', 'sprint_speed',
#        'agility', 'reactions', 'balance', 'shot_power', 'jumping', 'stamina',
#        'strength', 'long_shots', 'aggression', 'interceptions', 'positioning',
#        'vision', 'penalties', 'composure', 'marking', 'standing_tackle',
#        'sliding_tackle', 'GK_diving', 'GK_handling', 'GK_kicking',
#        'GK_positioning', 'GK_reflexes', 'tags', 'traits', 'LS', 'ST', 'RS',
#        'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM',
#        'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB',
#        'RCB', 'RB', 'PlayerLevel'],
#       dtype='object')

# %% [markdown]
# delete un use columns

# %%
# drop nulll & unusfull columns 
nullcols=['id', 'name', 'full_name', 'birth_date','national_team','national_rating','national_team_position','national_jersey_number','club_join_date','contract_end_year','tags','traits']
dataframe.drop(nullcols,axis=1,inplace=True)
dataframe.shape
# Out:
# (14363, 80)

# %% [markdown]
# sum of null

# %%
dataframe.isna().sum()
# Out:
# age               0
# height_cm         0
# weight_kgs        0
# positions         0
# nationality       0
#                ...
# LCB            1672
# CB             1672
# RCB            1672
# RB             1672
# PlayerLevel       0
# Length: 80, dtype: int64

# %% [markdown]
# know how max num of postions can player pkay on it

# %%
c= dataframe['positions'].str.split(',').max()
c # max num of position can player play on it in data is
# Out:
# ['ST', 'RWB', 'RM']

# %% [markdown]
# split position data

# %%
def spliPostion(data):
    max_values = np.max([
        data['positions'].apply(lambda x: len(str(x).split(','))).max(),
    ])
    return data['positions'].str.split(',').apply(lambda x: x + ['0'] * (max_values - len(x)))

# %%
# the lare number player can play in it is 3
play_postion = spliPostion(dataframe)
dataframe['position_first'] = play_postion.apply(lambda x: x[0])
dataframe['position_second'] = play_postion.apply(lambda x: x[1])
dataframe['position_third'] = play_postion.apply(lambda x: x[2])
dataframe.drop('positions', axis=1, inplace=True)

# %%
import joblib

# %%
from sklearn.preprocessing import LabelEncoder
transform=['nationality','preferred_foot','body_type','club_team''club_position','position_first','position_second','position_third']

le=LabelEncoder()
dataframe['nationality']=le.fit_transform(dataframe['nationality'])
joblib.dump(le,'predect/model/nationality_transform')

dataframe['preferred_foot']=le.fit_transform(dataframe['preferred_foot'])
joblib.dump(le,'predect/model/preferred_foot_transform')

dataframe['body_type']=le.fit_transform(dataframe['body_type'])
joblib.dump(le,'predect/model/body_type_transform')

dataframe['club_team']=le.fit_transform(dataframe['club_team'])
joblib.dump(le,'predect/model/club_team_transform')

dataframe['club_position']=le.fit_transform(dataframe['club_position'])
joblib.dump(le,'predect/model/club_position_transform')

dataframe['position_first']=le.fit_transform(dataframe['position_first'])
joblib.dump(le,'predect/model/position_first_transform')

dataframe['position_second']=le.fit_transform(dataframe['position_second'])
joblib.dump(le,'predect/model/position_second_transform')

dataframe['position_third']=le.fit_transform(dataframe['position_third'])
joblib.dump(le,'predect/model/position_third_transform')
# Out:
# ['predect/model/position_third_transform']

# %%
dataframe['upper_work_rate'] = dataframe['work_rate'].apply(lambda x: x.split('/')[0])
dataframe['down_work_rate'] = dataframe['work_rate'].apply(lambda x: x.split('/')[1])

# %%
dataframe['height_cm'] = dataframe['height_cm'].apply(lambda x:x/100)

# %%
dataframe.head(3)
# Out:
#    age  height_cm  weight_kgs  nationality  overall_rating  potential  \
# 0   26     1.7272        73.9           22              64         65
# 1   32     1.8796        79.8           76              72         72
# 2   24     1.7526        68.0          118              71         78
#
#       wage  preferred_foot  international_reputation(1-5)  weak_foot(1-5)  \
# 0   1000.0               1                              1               3
# 1  11000.0               1                              2               3
# 2  10000.0               1                              1               3
#
#    ...   LCB    CB   RCB    RB  PlayerLevel  position_first  position_second  \
# 0  ...  50+2  50+2  50+2  56+2            C               7               11
# 1  ...  71+2  71+2  71+2  58+2            A               1                0
# 2  ...  47+2  47+2  47+2  51+2            A              14                7
#
#    position_third  upper_work_rate  down_work_rate
# 0               0             High          Medium
# 1               0              Low          Medium
# 2               0             High          Medium
#
# [3 rows x 84 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
minmax=MinMaxScaler()
dataframe['release_clause_euro']=minmax.fit_transform(dataframe[['release_clause_euro']])
joblib.dump(minmax,'predect/model/minmax_release_clause_euro')
dataframe['wage']=minmax.fit_transform(dataframe[['wage']])
joblib.dump(minmax,'predect/model/wage_release_clause_euro')
# Out:
# ['predect/model/wage_release_clause_euro']

# %%
# rawan pre
columnsIter2 = pd.DataFrame(dataframe, columns=['LS','ST','RS','LW','LF','CF','RF','RW','LAM','CAM','RAM','LM','LCM','CM','RCM','RM','LWB','LDM','CDM','RDM','RWB','LB','LCB','CB','RCB','RB'],index=[dataframe.index])

for(columnName1, columnData1) in columnsIter2.iteritems():
    dataframe[columnName1] = dataframe[columnName1].str.replace('+', '.')
    dataframe[columnName1]= pd.to_numeric(dataframe[columnName1])

#for null numerical values:
columnsIter = pd.DataFrame(dataframe, columns=['LS','ST','RS','LW','LF','CF','RF','RW','LAM','CAM','RAM','LM','LCM','CM','RCM','RM','LWB','LDM','CDM','RDM','RWB','LB','LCB','CB','RCB','RB','wage','release_clause_euro','club_rating','club_jersey_number',],index=[dataframe.index])
for (columnName, columnData) in columnsIter.iteritems():
    dataframe[columnName] = dataframe[columnName].fillna(dataframe[columnName].mean())
# Out:
# C:\Users\EGYPT_~1\AppData\Local\Temp/ipykernel_9072/3504082149.py:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   dataframe[columnName1] = dataframe[columnName1].str.replace('+', '.')

# %%
dataframe.head()
# Out:
#    age  height_cm  weight_kgs  nationality  overall_rating  potential  \
# 0   26     1.7272        73.9           22              64         65
# 1   32     1.8796        79.8           76              72         72
# 2   24     1.7526        68.0          118              71         78
# 3   31     1.8796        83.0           44              72         72
# 4   24     1.7526        74.8           80              64         71
#
#        wage  preferred_foot  international_reputation(1-5)  weak_foot(1-5)  \
# 0  0.000000               1                              1               3
# 1  0.022026               1                              2               3
# 2  0.019824               1                              1               3
# 3  0.070485               0                              1               3
# 4  0.000000               1                              1               3
#
#    ...   LCB    CB   RCB    RB  PlayerLevel  position_first  position_second  \
# 0  ...  50.2  50.2  50.2  56.2            C               7               11
# 1  ...  71.2  71.2  71.2  58.2            A               1                0
# 2  ...  47.2  47.2  47.2  51.2            A              14                7
# 3  ...  70.2  70.2  70.2  70.2            A               6                9
# 4  ...  58.2  58.2  58.2  61.2            C              13               11
#
#    position_third  upper_work_rate  down_work_rate
# 0               0             High          Medium
# 1               0              Low          Medium
# 2               0             High          Medium
# 3               0             High            High
# 4               0           Medium          Medium
#
# [5 rows x 84 columns]

# %%
dataframe.isna().sum()
# Out:
# age                0
# height_cm          0
# weight_kgs         0
# nationality        0
# overall_rating     0
#                   ..
# position_first     0
# position_second    0
# position_third     0
# upper_work_rate    0
# down_work_rate     0
# Length: 84, dtype: int64

# %%
def convert_rate(col):
    dataframe[col]=le.fit_transform(dataframe[col])
    joblib.dump(le,'predect/model/'+col+'_predect')
    dataframe[col]=dataframe[col].apply(lambda x:x+1)

convert_rate('upper_work_rate')
convert_rate('down_work_rate')

# %%
dataframe['num_of_work_rate']=dataframe['upper_work_rate']/dataframe['down_work_rate']
dataframe['num_of_work_rate'].head()
# Out:
# 0    0.333333
# 1    0.666667
# 2    0.333333
# 3    1.000000
# 4    1.000000
# Name: num_of_work_rate, dtype: float64

# %%
dataframe.isna().sum()
# Out:
# age                 0
# height_cm           0
# weight_kgs          0
# nationality         0
# overall_rating      0
#                    ..
# position_second     0
# position_third      0
# upper_work_rate     0
# down_work_rate      0
# num_of_work_rate    0
# Length: 85, dtype: int64

# %%
dataframe= dataframe.drop(['work_rate'],axis=1)

# %%
dataframe.head()
# Out:
#    age  height_cm  weight_kgs  nationality  overall_rating  potential  \
# 0   26     1.7272        73.9           22              64         65
# 1   32     1.8796        79.8           76              72         72
# 2   24     1.7526        68.0          118              71         78
# 3   31     1.8796        83.0           44              72         72
# 4   24     1.7526        74.8           80              64         71
#
#        wage  preferred_foot  international_reputation(1-5)  weak_foot(1-5)  \
# 0  0.000000               1                              1               3
# 1  0.022026               1                              2               3
# 2  0.019824               1                              1               3
# 3  0.070485               0                              1               3
# 4  0.000000               1                              1               3
#
#    ...    CB   RCB    RB  PlayerLevel  position_first  position_second  \
# 0  ...  50.2  50.2  56.2            C               7               11
# 1  ...  71.2  71.2  58.2            A               1                0
# 2  ...  47.2  47.2  51.2            A              14                7
# 3  ...  70.2  70.2  70.2            A               6                9
# 4  ...  58.2  58.2  61.2            C              13               11
#
#    position_third  upper_work_rate  down_work_rate  num_of_work_rate
# 0               0                1               3          0.333333
# 1               0                2               3          0.666667
# 2               0                1               3          0.333333
# 3               0                1               1          1.000000
# 4               0                3               3          1.000000
#
# [5 rows x 84 columns]

# %%
modelLevel = LabelEncoder()

dataframe['PlayerLevel']=modelLevel.fit_transform(dataframe['PlayerLevel'])
joblib.dump(modelLevel,'predect/model/Leve_predect')
# Out:
# ['predect/model/Leve_predect']

# %%
dataframe['PlayerLevel'].head()
# Out:
# 0    2
# 1    0
# 2    0
# 3    0
# 4    2
# Name: PlayerLevel, dtype: int32

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as ptl

# %%
corr= dataframe.corr()
corr
# Out:
#                        age  height_cm  weight_kgs  nationality  \
# age               1.000000   0.063121    0.232562    -0.030962
# height_cm         0.063121   1.000000    0.496268     0.011706
# weight_kgs        0.232562   0.496268    1.000000    -0.020899
# nationality      -0.030962   0.011706   -0.020899     1.000000
# overall_rating    0.461709   0.038438    0.153005    -0.014997
# ...                    ...        ...         ...          ...
# position_second   0.001882  -0.229344   -0.249311    -0.003161
# position_third    0.015429  -0.122644   -0.123049    -0.000735
# upper_work_rate  -0.060157   0.156116    0.147193    -0.008952
# down_work_rate   -0.132238   0.010039   -0.019145     0.013251
# num_of_work_rate  0.077887   0.087577    0.105666    -0.012182
#
#                   overall_rating  potential      wage  preferred_foot  \
# age                     0.461709  -0.259687  0.153277       -0.006247
# height_cm               0.038438   0.007187  0.019711        0.045171
# weight_kgs              0.153005  -0.012678  0.065150        0.065109
# nationality            -0.014997   0.001516 -0.023679        0.009471
# overall_rating          1.000000   0.646751  0.575064       -0.054320
# ...                          ...        ...       ...             ...
# position_second         0.118011   0.072618  0.044462       -0.049144
# position_third          0.085276   0.044611  0.029973       -0.007364
# upper_work_rate        -0.206055  -0.132660 -0.131486        0.056689
# down_work_rate         -0.182168  -0.076887 -0.103627       -0.022261
# num_of_work_rate        0.033736  -0.013337  0.005959        0.045078
#
#                   international_reputation(1-5)  weak_foot(1-5)  ...  \
# age                                    0.256339        0.059249  ...
# height_cm                              0.027580       -0.130777  ...
# weight_kgs                             0.090888       -0.129177  ...
# nationality                           -0.012243        0.000322  ...
# overall_rating                         0.487549        0.216293  ...
# ...                                         ...             ...  ...
# position_second                        0.010953        0.173839  ...
# position_third                         0.013786        0.122547  ...
# upper_work_rate                       -0.085270       -0.155279  ...
# down_work_rate                        -0.087424       -0.064390  ...
# num_of_work_rate                       0.017033       -0.049215  ...
#
#                         CB       RCB        RB  PlayerLevel  position_first  \
# age               0.313415  0.313415  0.290202    -0.088467       -0.048483
# height_cm         0.154043  0.154043  0.009108     0.009727       -0.130866
# weight_kgs        0.268441  0.268441  0.079807    -0.002935       -0.109900
# nationality       0.002451  0.002451  0.004552     0.007807        0.013598
# overall_rating    0.431374  0.431374  0.527953    -0.129349       -0.023841
# ...                    ...       ...       ...          ...             ...
# position_second  -0.114263 -0.114263  0.022051    -0.069906        0.095679
# position_third   -0.083954 -0.083954  0.000757    -0.047537        0.057477
# upper_work_rate   0.052487  0.052487 -0.044167     0.035434       -0.220673
# down_work_rate   -0.209874 -0.209874 -0.183217     0.027519        0.081023
# num_of_work_rate  0.266124  0.266124  0.176365    -0.002334       -0.239812
#
#                   position_second  position_third  upper_work_rate  \
# age                      0.001882        0.015429        -0.060157
# height_cm               -0.229344       -0.122644         0.156116
# weight_kgs              -0.249311       -0.123049         0.147193
# nationality             -0.003161       -0.000735        -0.008952
# overall_rating           0.118011        0.085276        -0.206055
# ...                           ...             ...              ...
# position_second          1.000000        0.334043        -0.180419
# position_third           0.334043        1.000000        -0.120592
# upper_work_rate         -0.180419       -0.120592         1.000000
# down_work_rate          -0.037696       -0.026443         0.129248
# num_of_work_rate        -0.079280       -0.055878         0.500606
#
#                   down_work_rate  num_of_work_rate
# age                    -0.132238          0.077887
# height_cm               0.010039          0.087577
# weight_kgs             -0.019145          0.105666
# nationality             0.013251         -0.012182
# overall_rating         -0.182168          0.033736
# ...                          ...               ...
# position_second        -0.037696         -0.079280
# position_third         -0.026443         -0.055878
# upper_work_rate         0.129248          0.500606
# down_work_rate          1.000000         -0.722974
# num_of_work_rate       -0.722974          1.000000
#
# [84 rows x 84 columns]

# %%
'''ptl.figure(figsize=(50,50))
sns.set_context('paper',font_scale=1)
sns.heatmap(corr,annot=True)'''
# Out:
# "ptl.figure(figsize=(50,50))\nsns.set_context('paper',font_scale=1)\nsns.heatmap(corr,annot=True)"

# %%
top_feature = corr.index[abs(corr['PlayerLevel'])>0.0]
top_feature
# Out:
# Index(['age', 'height_cm', 'weight_kgs', 'nationality', 'overall_rating',
#        'potential', 'wage', 'preferred_foot', 'international_reputation(1-5)',
#        'weak_foot(1-5)', 'skill_moves(1-5)', 'body_type',
#        'release_clause_euro', 'club_team', 'club_rating', 'club_position',
#        'club_jersey_number', 'crossing', 'finishing', 'heading_accuracy',
#        'short_passing', 'volleys', 'dribbling', 'curve', 'freekick_accuracy',
#        'long_passing', 'ball_control', 'acceleration', 'sprint_speed',
#        'agility', 'reactions', 'balance', 'shot_power', 'jumping', 'stamina',
#        'strength', 'long_shots', 'aggression', 'interceptions', 'positioning',
#        'vision', 'penalties', 'composure', 'marking', 'standing_tackle',
#        'sliding_tackle', 'GK_diving', 'GK_handling', 'GK_kicking',
#        'GK_positioning', 'GK_reflexes', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF',
#        'RF', 'RW', 'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB',
#        'LDM', 'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB',
#        'PlayerLevel', 'position_first', 'position_second', 'position_third',
#        'upper_work_rate', 'down_work_rate', 'num_of_work_rate'],
#       dtype='object')

# %%
df=dataframe[top_feature]
df.head(1)
# Out:
#    age  height_cm  weight_kgs  nationality  overall_rating  potential  wage  \
# 0   26     1.7272        73.9           22              64         65   0.0
#
#    preferred_foot  international_reputation(1-5)  weak_foot(1-5)  ...    CB  \
# 0               1                              1               3  ...  50.2
#
#     RCB    RB  PlayerLevel  position_first  position_second  position_third  \
# 0  50.2  56.2            2               7               11               0
#
#    upper_work_rate  down_work_rate  num_of_work_rate
# 0                1               3          0.333333
#
# [1 rows x 84 columns]

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV

# %%
x=df.drop(['PlayerLevel'],axis=1)
y=df['PlayerLevel']

# %% [markdown]
#     'SVC': {
#         'model': SVC(gamma='auto'),
#         'params': {
#             'C': [5, 10, 15, 20],
#             'kernel': ['linear', 'rbf', 'sigmoid', 'precomputed']
#         }
#     },

# %%
# dic
model_params = {
     'SVC': {
        'model': SVC(gamma='auto',max_iter=20000000),
        'params': {
            'C': [.1,0.01,0.001],
            'kernel': ['linear', 'rbf',]

        }
    },
    "LogisticRegression": {
    'model': LogisticRegression(),
    'params': {
        'C': [1, 5, 10, 15]
    }
        },
    "GaussianNB": {
        'model': GaussianNB(),
        'params': {

        }
    },
    "MultinomialNB": {
        'model': MultinomialNB(),
        'params': {
            'alpha': [1, 2, 3, 4],
            'fit_prior': [True, False],

        }
    },
    "DecisionTreeClassifier": {
        'model': DecisionTreeClassifier(),
        'params': {
            'criterion': ["gini", "entropy"],
            'splitter': ["best", "random"],
            'max_depth': [5, 10, 15, 20],
            'max_features': ["auto", "sqrt", "log2"]
        }
    }
    
}

# %%
'''"LogisticRegression":{
    'model':LogisticRegression(),
    'params':{
        'C':[1,5,10,15]
    }
},'''
# Out:
# '"LogisticRegression":{\n    \'model\':LogisticRegression(),\n    \'params\':{\n        \'C\':[1,5,10,15]\n    }\n},'

# %%
'''scorre=[]
for mn,mp in model_params.items():
    clf=GridSearchCV(mp['model'],mp['params'],cv=3,return_train_score=False)
    clf.fit(x,y)
    scorre.append({
        'model name ': mn,
        'best_score':clf.best_score_,
        'best_params':clf.best_params_,
    })

d=pd.DataFrame(scorre)
d'''
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
dataframe=shuffle(dataframe)
x,xt,y,yt=train_test_split(dataframe.drop(['PlayerLevel'],axis=1),dataframe['PlayerLevel'],train_size=.8,random_state=0)

# %%
import time
from sklearn.model_selection import GridSearchCV
scorre=[]
for mn,mp in model_params.items():
    clf=GridSearchCV(mp['model'],mp['params'],cv=5,return_train_score=False)
    tic=time.time()
    clf.fit(dataframe.drop(['PlayerLevel'],axis=1),dataframe['PlayerLevel'])
    toc=time.time()
    scorre.append({
        'model name ': mn,
        'best_score':clf.best_score_,
        'best_params':clf.best_params_,
        'trainTime':toc-tic
    })
    

df=pd.DataFrame(scorre)
df
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\svm\_base.py:255: ConvergenceWarning: Solver terminated early (max_iter=20000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\svm\_base.py:255: ConvergenceWarning: Solver terminated early (max_iter=20000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\svm\_base.py:255: ConvergenceWarning: Solver terminated early (max_iter=20000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\svm\_base.py:255: ConvergenceWarning: Solver terminated early (max_iter=20000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\svm\_base.py:255: ConvergenceWarning: Solver terminated early (max_iter=20000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#               model name   best_score  \
# 0                     SVC    0.891108
# 1      LogisticRegression    0.520921
# 2              GaussianNB    0.583443
# 3           MultinomialNB    0.283994
# 4  DecisionTreeClassifier    0.822043
#
#                                          best_params    trainTime
# 0                    {'C': 0.01, 'kernel': 'linear'}  1107.605978
# 1                                           {'C': 1}    10.954558
# 2                                                 {}     0.244684
# 3                    {'alpha': 1, 'fit_prior': True}     0.750566
# 4  {'criterion': 'gini', 'max_depth': 10, 'max_fe...     8.217775

# %%
df['best_params'][3]
# Out:
# {'criterion': 'gini',
#  'max_depth': 10,
#  'max_features': 'auto',
#  'splitter': 'best'}

# %%
model=DecisionTreeClassifier(criterion='gini',max_depth=15,max_features='auto',splitter='best')
tic=time.time()
model.fit(x,y)
toc=time.time()
joblib.dump(model,'predect/model/Class_predect')
toc-tic
# Out:
# 0.054818153381347656

# %%
tic=time.time()
model.score(xt,yt)
toc=time.time()
toc-tic
# Out:
# 0.004982709884643555

# %%
from sklearn.svm import SVC

# %%
svc=SVC(C=0.01,max_iter=20000000,kernel='linear')
tic=time.time()
svc.fit(x,y)
toc=time.time()
joblib.dump(svc,'predect/model/ClassSVC_predect')
# Out:
# ['predect/model/ClassSVC_predect']

# %%
tic-toc
# Out:
# -17.938226222991943

# %%
svc.score(xt,yt)
# Out:
# 0.901496693351897

# %% [markdown]
# ## outlayers

# %%
'''
1- import helper lips
2- read data fromcsv
3- print data info
4- print data describe
5- print data columns names
6- drop nulll & unusfull columns 
7- print fraction of null valuses in columns
8- split column position 
9- give new columns of pposition values
10- lable Encoder form uon numecic data
11- split work rate in to  upper_work_rate & down_work_rate
12- scaling large values ( MinMaxScaler )
13- columns of ( + ) split and sum values to gether
14- lable Encoder upper_work_rate & down_work_rate
15- devide 2 columns
16- fill null values of mean values
17- remove the outlayer
18- get csv file from dataframe (clean_data1.csv)
'''
# Out:
# '\n1- import helper lips\n2- read data fromcsv\n3- print data info\n4- print data describe\n5- print data columns names\n6- drop nulll & unusfull columns \n7- print fraction of null valuses in columns\n8- split column position \n9- give new columns of pposition values\n10- lable Encoder form uon numecic data\n11- split work rate in to  upper_work_rate & down_work_rate\n12- scaling large values ( MinMaxScaler )\n13- columns of ( + ) split and sum values to gether\n14- lable Encoder upper_work_rate & down_work_rate\n15- devide 2 columns\n16- fill null values of mean values\n17- remove the outlayer\n18- get csv file from dataframe (clean_data1.csv)\n'

# %%
import matplotlib.pyplot as plt
Models = ['SVC','DecisionTree','GaussianNB','LogisticRegression','MultinomialNB',]
logisticRegression=0.5*100
gaussianNB=0.58*100
multinomialNB=0.28*100
decisionTree=0.82*100
svc=0.89*100
acc = [svc,decisionTree,gaussianNB,logisticRegression,multinomialNB,]

New_Colors = ['lightseagreen','darkturquoise','steelblue','cadetblue','dodgerblue']
plt.bar(Models, acc, color=New_Colors)
plt.title('Models accuracy', fontsize=14)
plt.xticks(rotation=90)
plt.grid(True)
plt.show()
