# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as ptl

# %%
data=pd.read_csv("player_date_with_no_outlayer_with_no_scaller.csv")
print(data.shape)
data.head()
# Out:
# (12598, 86)
#    Unnamed: 0  Unnamed: 0.1  age  height_cm  weight_kgs  nationality  \
# 0           0             0   26     1.7272        73.9           22
# 1           1             1   32     1.8796        79.8           76
# 2           2             2   24     1.7526        68.0          118
# 3           3             3   31     1.8796        83.0           44
# 4           4             4   24     1.7526        74.8           80
#
#    overall_rating  potential     wage  preferred_foot  ...    CB   RCB    RB  \
# 0              64         65   1000.0               1  ...  52.0  52.0  58.0
# 1              72         72  11000.0               1  ...  73.0  73.0  60.0
# 2              71         78  10000.0               1  ...  49.0  49.0  53.0
# 3              72         72  33000.0               0  ...  72.0  72.0  72.0
# 4              64         71   1000.0               1  ...  60.0  60.0  63.0
#
#        value  position_first  position_second  position_third  \
# 0   525000.0               7               11               0
# 1  1800000.0               1                0               0
# 2  3400000.0              14                7               0
# 3  2200000.0               6                9               0
# 4   525000.0              13               11               0
#
#    upper_work_rate  down_work_rate  num_of_work_rate
# 0                1               3          0.333333
# 1                2               3          0.666667
# 2                1               3          0.333333
# 3                1               1          1.000000
# 4                3               3          1.000000
#
# [5 rows x 86 columns]

# %%
corr= data.corr()
corr
# Out:
#                   Unnamed: 0  Unnamed: 0.1       age  height_cm  weight_kgs  \
# Unnamed: 0          1.000000      1.000000  0.011736   0.001789   -0.009350
# Unnamed: 0.1        1.000000      1.000000  0.011736   0.001789   -0.009350
# age                 0.011736      0.011736  1.000000   0.064455    0.238344
# height_cm           0.001789      0.001789  0.064455   1.000000    0.494736
# weight_kgs         -0.009350     -0.009350  0.238344   0.494736    1.000000
# ...                      ...           ...       ...        ...         ...
# position_second     0.008858      0.008858  0.007630  -0.221869   -0.241943
# position_third      0.004339      0.004339  0.020720  -0.117886   -0.116906
# upper_work_rate    -0.012328     -0.012328 -0.061613   0.143427    0.144274
# down_work_rate      0.002658      0.002658 -0.133772   0.014802   -0.010304
# num_of_work_rate   -0.014544     -0.014544  0.079057   0.072507    0.095093
#
#                   nationality  overall_rating  potential      wage  \
# Unnamed: 0          -0.004803       -0.000636  -0.011873  0.009704
# Unnamed: 0.1        -0.004803       -0.000636  -0.011873  0.009704
# age                 -0.031627        0.539554  -0.352586  0.280392
# height_cm            0.012074        0.041004  -0.001765  0.025484
# weight_kgs          -0.009525        0.159080  -0.054363  0.084882
# ...                       ...             ...        ...       ...
# position_second     -0.007695        0.122505   0.059289  0.042406
# position_third       0.000939        0.091390   0.032595  0.045776
# upper_work_rate     -0.014351       -0.164627  -0.069774 -0.102531
# down_work_rate       0.007717       -0.165920  -0.031060 -0.097143
# num_of_work_rate    -0.012462        0.048384  -0.012885  0.022007
#
#                   preferred_foot  ...        CB       RCB        RB     value  \
# Unnamed: 0              0.010806  ... -0.003998 -0.003998  0.001406 -0.001321
# Unnamed: 0.1            0.010806  ... -0.003998 -0.003998  0.001406 -0.001321
# age                    -0.012798  ...  0.337290  0.337290  0.315759  0.180009
# height_cm               0.044230  ...  0.150745  0.150745  0.008465  0.007265
# weight_kgs              0.065032  ...  0.269634  0.269634  0.081668  0.053996
# ...                          ...  ...       ...       ...       ...       ...
# position_second        -0.053609  ... -0.114310 -0.114310  0.016459  0.095892
# position_third         -0.008041  ... -0.078977 -0.078977  0.002874  0.073573
# upper_work_rate         0.058751  ...  0.076328  0.076328 -0.004282 -0.149647
# down_work_rate         -0.018594  ... -0.178182 -0.178182 -0.146923 -0.114648
# num_of_work_rate        0.042825  ...  0.255918  0.255918  0.173435  0.004883
#
#                   position_first  position_second  position_third  \
# Unnamed: 0              0.009672         0.008858        0.004339
# Unnamed: 0.1            0.009672         0.008858        0.004339
# age                    -0.057328         0.007630        0.020720
# height_cm              -0.131249        -0.221869       -0.117886
# weight_kgs             -0.114276        -0.241943       -0.116906
# ...                          ...              ...             ...
# position_second         0.098083         1.000000        0.336945
# position_third          0.065592         0.336945        1.000000
# upper_work_rate        -0.214541        -0.174889       -0.111979
# down_work_rate          0.073604        -0.046144       -0.035417
# num_of_work_rate       -0.227908        -0.067245       -0.041269
#
#                   upper_work_rate  down_work_rate  num_of_work_rate
# Unnamed: 0              -0.012328        0.002658         -0.014544
# Unnamed: 0.1            -0.012328        0.002658         -0.014544
# age                     -0.061613       -0.133772          0.079057
# height_cm                0.143427        0.014802          0.072507
# weight_kgs               0.144274       -0.010304          0.095093
# ...                           ...             ...               ...
# position_second         -0.174889       -0.046144         -0.067245
# position_third          -0.111979       -0.035417         -0.041269
# upper_work_rate          1.000000        0.131053          0.486887
# down_work_rate           0.131053        1.000000         -0.734878
# num_of_work_rate         0.486887       -0.734878          1.000000
#
# [86 rows x 86 columns]

# %%
ptl.figure(figsize=(50,50))
sns.set_context('paper',font_scale=1)
sns.heatmap(data.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
corr
# Out:
#                   Unnamed: 0  Unnamed: 0.1       age  height_cm  weight_kgs  \
# Unnamed: 0          1.000000      1.000000  0.011736   0.001789   -0.009350
# Unnamed: 0.1        1.000000      1.000000  0.011736   0.001789   -0.009350
# age                 0.011736      0.011736  1.000000   0.064455    0.238344
# height_cm           0.001789      0.001789  0.064455   1.000000    0.494736
# weight_kgs         -0.009350     -0.009350  0.238344   0.494736    1.000000
# ...                      ...           ...       ...        ...         ...
# position_second     0.008858      0.008858  0.007630  -0.221869   -0.241943
# position_third      0.004339      0.004339  0.020720  -0.117886   -0.116906
# upper_work_rate    -0.012328     -0.012328 -0.061613   0.143427    0.144274
# down_work_rate      0.002658      0.002658 -0.133772   0.014802   -0.010304
# num_of_work_rate   -0.014544     -0.014544  0.079057   0.072507    0.095093
#
#                   nationality  overall_rating  potential      wage  \
# Unnamed: 0          -0.004803       -0.000636  -0.011873  0.009704
# Unnamed: 0.1        -0.004803       -0.000636  -0.011873  0.009704
# age                 -0.031627        0.539554  -0.352586  0.280392
# height_cm            0.012074        0.041004  -0.001765  0.025484
# weight_kgs          -0.009525        0.159080  -0.054363  0.084882
# ...                       ...             ...        ...       ...
# position_second     -0.007695        0.122505   0.059289  0.042406
# position_third       0.000939        0.091390   0.032595  0.045776
# upper_work_rate     -0.014351       -0.164627  -0.069774 -0.102531
# down_work_rate       0.007717       -0.165920  -0.031060 -0.097143
# num_of_work_rate    -0.012462        0.048384  -0.012885  0.022007
#
#                   preferred_foot  ...        CB       RCB        RB     value  \
# Unnamed: 0              0.010806  ... -0.003998 -0.003998  0.001406 -0.001321
# Unnamed: 0.1            0.010806  ... -0.003998 -0.003998  0.001406 -0.001321
# age                    -0.012798  ...  0.337290  0.337290  0.315759  0.180009
# height_cm               0.044230  ...  0.150745  0.150745  0.008465  0.007265
# weight_kgs              0.065032  ...  0.269634  0.269634  0.081668  0.053996
# ...                          ...  ...       ...       ...       ...       ...
# position_second        -0.053609  ... -0.114310 -0.114310  0.016459  0.095892
# position_third         -0.008041  ... -0.078977 -0.078977  0.002874  0.073573
# upper_work_rate         0.058751  ...  0.076328  0.076328 -0.004282 -0.149647
# down_work_rate         -0.018594  ... -0.178182 -0.178182 -0.146923 -0.114648
# num_of_work_rate        0.042825  ...  0.255918  0.255918  0.173435  0.004883
#
#                   position_first  position_second  position_third  \
# Unnamed: 0              0.009672         0.008858        0.004339
# Unnamed: 0.1            0.009672         0.008858        0.004339
# age                    -0.057328         0.007630        0.020720
# height_cm              -0.131249        -0.221869       -0.117886
# weight_kgs             -0.114276        -0.241943       -0.116906
# ...                          ...              ...             ...
# position_second         0.098083         1.000000        0.336945
# position_third          0.065592         0.336945        1.000000
# upper_work_rate        -0.214541        -0.174889       -0.111979
# down_work_rate          0.073604        -0.046144       -0.035417
# num_of_work_rate       -0.227908        -0.067245       -0.041269
#
#                   upper_work_rate  down_work_rate  num_of_work_rate
# Unnamed: 0              -0.012328        0.002658         -0.014544
# Unnamed: 0.1            -0.012328        0.002658         -0.014544
# age                     -0.061613       -0.133772          0.079057
# height_cm                0.143427        0.014802          0.072507
# weight_kgs               0.144274       -0.010304          0.095093
# ...                           ...             ...               ...
# position_second         -0.174889       -0.046144         -0.067245
# position_third          -0.111979       -0.035417         -0.041269
# upper_work_rate          1.000000        0.131053          0.486887
# down_work_rate           0.131053        1.000000         -0.734878
# num_of_work_rate         0.486887       -0.734878          1.000000
#
# [86 rows x 86 columns]

# %%
top_feature = corr.index[abs(corr['value'])>0.5]
top_feature
# Out:
# Index(['overall_rating', 'potential', 'wage', 'release_clause_euro',
#        'reactions', 'value'],
#       dtype='object')

# %%
df=data[top_feature]
print(df.shape)
df.head()
# Out:
# (12598, 6)
#    overall_rating  potential     wage  release_clause_euro  reactions  \
# 0              64         65   1000.0             801000.0         61
# 1              72         72  11000.0            3200000.0         65
# 2              71         78  10000.0            7100000.0         64
# 3              72         72  33000.0            4300000.0         68
# 4              64         71   1000.0             761000.0         60
#
#        value
# 0   525000.0
# 1  1800000.0
# 2  3400000.0
# 3  2200000.0
# 4   525000.0

# %%
ptl.figure(figsize=(50,50))
sns.set_context('paper',font_scale=1.4)
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
df.to_csv("data_with_feature_chooseing.csv")

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

# %%
poly=PolynomialFeatures(degree=3)
xpoly=poly.fit_transform(df.drop(['value',],axis=1))
poly.fit(xpoly,df['value'])
# Out:
# PolynomialFeatures(degree=3)

# %%
xtrain,xtest,ytrain,ytest=train_test_split(xpoly,df['value'],train_size=0.8)

# %%
model=LinearRegression()

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(LinearRegression(),xtrain,ytrain,cv=30)
# Out:
# array([0.6829043 , 0.93315589, 0.91762001, 0.94008617, 0.92111139,
#        0.86366124, 0.89778564, 0.94168674, 0.91936132, 0.91379551,
#        0.95362079, 0.88705558, 0.87684291, 0.90851655, 0.92690825,
#        0.90000109, 0.92003564, 0.89377439, 0.9189161 , 0.91440078,
#        0.89299979, 0.93881773, 0.91515931, 0.9036364 , 0.89999615,
#        0.84272581, 0.91544697, 0.89341342, 0.91710948, 0.93985346])

# %%
model.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
model.score(xtest,ytest)
# Out:
# 0.8940178646292383
